# %%
# Create a scatter plot function

def plot_overperformers_scatter(df, top_n=10):
    """
    Create a scatter plot for overperforming players based on their goals and non-penalty expected goals (npxG).
    Highlights top N overperformers by z-score and annotates with player names.
    
    Parameters:
        df (pd.DataFrame): The cleaned DataFrame containing player data with z-scores and overperformance flags.
        top_n (int): The number of top overperformers to highlight based on z-score.
    """
    # Step 1: Filter the overperformers
    overperformers = df[df['overperforming'] == True]

    # Step 2: Sort the overperformers to highlight the top N based on z-score
    #top_overperformers = overperformers.sort_values(by='overperformance', ascending=False).head(top_n)
    top_overperformers = overperformers.sort_values(by='z_score_overperformance', ascending=False).head(top_n)


    # Step 3: Create a scatter plot
    fig = plt.figure(figsize=(12, 12), dpi=100, facecolor='#F1E5E1')
    ax = plt.subplot(facecolor='#F1E5E1')  # Set axes background color
    ax.grid(visible=True, ls='--', color='lightgrey')

    # Scatter plot for overperformers
    scatter = ax.scatter(overperformers['npxG'], overperformers['npG'], 
                         c=overperformers['overperformance'], cmap='inferno', 
                         zorder=3, ec='grey', s=50, alpha=0.7)

    # Add labels and title
    plt.xlabel('Non-penalty expected Goals (npxG)')
    plt.ylabel('Non-penalty goals scored (npG)')
    plt.title("Europe's Most Lethal Attackers", weight='bold', pad=50)

    # Color bar to show the z-scores
    #plt.colorbar(scatter, label='Z-Score (Goals)')

    # Step 4: Annotate the top N overperformers with their player names
    texts = []  # Prepare the list to store text objects
    for i in range(len(top_overperformers)):
        text = ax.text(top_overperformers.iloc[i]['npxG'], 
                       top_overperformers.iloc[i]['npG'], 
                       top_overperformers.iloc[i]['Player'],
                       path_effects=[path_effects.Stroke(linewidth=2, foreground=fig.get_facecolor()), path_effects.Normal()], 
                       fontsize=9, 
                       ha='center', 
                       color='black', 
                       weight='bold')
        texts.append(text)  # Add the text object to the list

    # Step 5: Adjust the ticks on the x and y axes to use integer ticks
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))  # Set integer ticks for x-axis
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))  # Set integer ticks for y-axis

    # Optional: Customize the x and y axis limits (if needed)
    ax.set_xlim(left=0, right=20)  # Example: set x-axis limits
    ax.set_ylim(bottom=0, top=30)  # Example: set y-axis limits
    
    # Adjust the text positions to prevent overlapping
    adjust_text(texts, only_move={'points': 'y', 'text': 'xy', 'objects': 'xy'})

    # Add footer text
    plt.figtext(
        x=0.09, y=0.92, 
        s="Non-penalty expected goals and Non-penalty goals scored across Europe's Big 5 leagues",
        va="bottom", ha="left", fontsize=9, color="#5A5A5A"
    )

    plt.figtext(
        x=0.09, y=0.89, 
        s="Only forwards with above median minutes are shown \nViz by @jsonrbrt.bsky.social | Season 2024/2025",
        va="bottom", ha="left", fontsize=9, color="#5A5A5A"
    )

    # Show the plot
    plt.show()

# %%
# V 1.2
    # Annotate the top N overperformers with their player names
    texts = []
    for _, row in top_overperformers.iterrows():
        text = ax.text(
        row['npxG'] + 0.1,  # horizontal offset
        row['npG'] + 0.1,   # vertical offset
        row['Player'],
        fontsize=9,
        ha='center',
        va='top',
        color='black',
        weight='bold',
        path_effects=[
        path_effects.Stroke(linewidth=1, foreground=fig.get_facecolor()),
            path_effects.Normal()
        ]
        )
        texts.append(text)

    # Adjust text with arrows (leader lines)
    adjust_text(
        texts,
        arrowprops=dict(arrowstyle="-", color='gray', lw=0.8),
        only_move={'points': 'y', 'text': 'xy'},
        expand_points=(1.2, 1.2),
        expand_text=(1.2, 1.2),
        force_text=0.75
    )

# V 0.1
    # Annotate top players
    texts = []
    for _, row in top_overperformers.iterrows():
        text = ax.text(row['npxG'], row['npG'], row['Player'],
                       path_effects=[path_effects.Stroke(linewidth=2, foreground=fig.get_facecolor()), path_effects.Normal()],
                       fontsize=9, ha='center', color='black', weight='bold')
        texts.append(text)

# %%
def plot_overperformers_scatter(df, top_n=10):
    """
    Create a scatter plot of npG vs npxG for all eligible forwards, highlighting top N overperformers.

    Parameters:
        df (pd.DataFrame): Cleaned DataFrame containing 'npG', 'npxG', 'overperformance', 'minutes', etc.
        top_n (int): Number of top overperformers to annotate.
    """
    # Step 1: Filter players above median minutes
    median_minutes = df['minutes'].median()
    eligible_players = df[df['minutes'] > median_minutes]

    # Step 2: Get top N overperformers
    top_overperformers = eligible_players[eligible_players['overperforming'] == True] \
                            .sort_values(by='overperformance', ascending=False) \
                            .head(top_n)

    # Step 3: Setup figure and axis
    fig, ax = plt.subplots(figsize=(12, 12), dpi=100, facecolor='#F1E5E1')
    ax.set_facecolor('#F1E5E1')
    ax.grid(visible=True, ls='--', color='lightgrey')

    # Step 4: Plot all players with low opacity
    ax.scatter(
        eligible_players['npxG'], eligible_players['npG'],
        color='gray', alpha=0.2, s=50, label='All Forwards', zorder=1
    )

    # Step 5: Plot top overperformers with color
    scatter = ax.scatter(
        top_overperformers['npxG'], top_overperformers['npG'],
        c=top_overperformers['overperformance'], cmap='inferno',
        edgecolor='black', s=80, zorder=2, label='Top Overperformers'
    )

    # Step 6: Diagonal reference line (npG = npxG)
    max_val = max(eligible_players['npxG'].max(), eligible_players['npG'].max()) + 1
    ax.plot([0, max_val], [0, max_val], '--', color='black', lw=1, zorder=0)

    # Step 7: Annotate top performers
    texts = []
    for _, row in top_overperformers.iterrows():
        # Place label above and to the right, and draw a line to the point
        text = ax.text(
            row['npxG'] + 0.2, row['npG'] + 0.2, row['Player'],
            fontsize=9, ha='left', va='bottom', weight='bold',
            path_effects=[
                path_effects.Stroke(linewidth=3, foreground=fig.get_facecolor()),
                path_effects.Normal()
            ],
            zorder=3
        )
        texts.append(text)
        # Draw line from text to point
        ax.plot([row['npxG'], row['npxG'] + 0.2], [row['npG'], row['npG'] + 0.2],
                color='black', lw=0.5, linestyle='-', zorder=2)

    # Step 8: Formatting
    ax.set_xlabel('Non-penalty expected Goals (npxG)', fontsize=12)
    ax.set_ylabel('Non-penalty Goals Scored (npG)', fontsize=12)
    ax.set_title("Europe's Most Lethal Attackers", fontsize=16, weight='bold', pad=40)

    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))

    ax.set_xlim(left=0)
    ax.set_ylim(bottom=0)

    adjust_text(texts, only_move={'points': 'y', 'text': 'xy', 'objects': 'xy'})

    # Step 9: Footnotes
    plt.figtext(
        x=0.09, y=0.955,
        s="Non-penalty expected goals and Non-penalty goals scored across Europe's Big 5 leagues",
        va="bottom", ha="left", fontsize=9, color="#5A5A5A"
    )

    plt.figtext(
        x=0.09, y=0.93,
        s="Only forwards with above median minutes are shown \nViz by @jsonrbrt.bsky.social | Season 2024/2025",
        va="bottom", ha="left", fontsize=9, color="#5A5A5A"
    )

    # Step 10: Legend and show
    ax.legend()
    plt.tight_layout()
    plt.show()

# %%
plot_overperformers_scatter(df, 10)

# %%
def clean_table_df(df):
    """
    Clean and process the input DataFrame by converting necessary columns, 
    creating new columns, sorting, and filtering out rows with missing data.
    
    Parameters:
    - df: The input DataFrame containing player data.
    
    Returns:
    - A cleaned and processed DataFrame.
    """
    # Convert the 'goals' and penalty kick ('PK') into integer type
    df['Gls'] = df['Gls'].astype(int)
    df['PK'] = df['PK'].astype(int)
    
    # Create a new column called Non-Penalty Goals ('nPG')
    df['npG'] = df['Gls'] - df['PK']
    
    # Sort the dataframe by 'nPG'
    df = df.sort_values(by='npG', ascending=False).reset_index(drop=True)
    
    # Filter out rows where squad is missing a value
    df = df[~df['Squad'].isna()]
    
    return df

# %%
clean_df = clean_table_df(table_df)
clean_df
# Out:
# /var/folders/vw/4r9rm0553n95pm4ckhlrdctr0000gn/T/ipykernel_91213/3210943079.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gls'] = df['Gls'].astype(int)
# /var/folders/vw/4r9rm0553n95pm4ckhlrdctr0000gn/T/ipykernel_91213/3210943079.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PK'] = df['PK'].astype(int)
# /var/folders/vw/4r9rm0553n95pm4ckhlrdctr0000gn/T/ipykernel_91213/3210943079.py:17: SettingWithCopyWarning:
# ...

# %% [markdown]
# ### Analyzing Europe's top forwards
# #### The previous function analyzed overperformance using: z_score_goals = (Gls - mean_Gls) / std_Gls
# #### This approach is potentiall flawed since a player with high number of goals and non-penalty expected goals may be flagged as overperforming and vice versa despite the chance quality

# %%
# Import the required libraries

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patheffects as path_effects
from matplotlib.ticker import MaxNLocator
import seaborn as sns
from adjustText import adjust_text
from mplsoccer import Pitch
from PIL import Image
import urllib
import os

# %%
# Create a function to access data from FBRef
# For this analysis the data required is shooting data from Big 5 European Leagues

def access_player_shooting_data(url):
    try:
        # Read all tables from the webpage
        tables = pd.read_html(url, attrs={'id': 'stats_shooting'})
        
        # Check if the table exists
        if tables:
            return tables[0]  # Return the first table
        else:
            print("No table found with the specified ID.")
            return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
# Provide the URL, save it into a variable called 'url'
url = 'https://fbref.com/en/comps/Big5/shooting/players/Big-5-European-Leagues-Stats'

# Call the function and save it to a variable called 'df'
df = access_player_shooting_data(url)

# %%
# Check the dataframe
df.head(10)
# Out:
#   Unnamed: 0_level_0   Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                   Rk               Player             Nation
# 0                  1           Max Aarons            eng ENG
# 1                  2           Max Aarons            eng ENG
# 2                  3       Rodrigo Abajas             es ESP
# 3                  4       James Abankwah             ie IRL
# 4                  5    Keyliane Abdallah             fr FRA
# 5                  6     Yunis Abdelhamid             ma MAR
# 6                  7        Himad Abdelli             dz ALG
# 7                  8  Mohamed Abdelmoneim             eg EGY
# 8                  9             Ali Abdi             tn TUN
# 9                 10      Saud Abdulhamid             sa KSA
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0  Unnamed: 5_level_0  \
#                  Pos              Squad                Comp
# 0                 DF        Bournemouth  eng Premier League
# ...

# %%
# Create a function to clean the dataframe

def clean_data(df):
    # Drop the top level columns (if multi-index)
    if df.columns.nlevels > 1:
        df = df.droplevel(0, axis=1)
    
    # Drop the 'Matches' column if it exists
    if 'Matches' in df.columns:
        df = df.drop('Matches', axis=1)
    
    # Convert the values in '90s' to numeric values, coercing errors
    df['90s'] = pd.to_numeric(df['90s'], errors='coerce')

    # Fill NaN values with 0.0
    df.fillna(0.0, inplace=True)

    # Convert '90s' into a float and create the 'minutes' column
    df['90s'] = df['90s'].astype(float)
    df['minutes'] = (df['90s'] * 90).round().astype(int)

    # Filter players based on position (e.g., only forwards 'FW')
    df = df[df['Pos'].str.contains('FW', na=False)]  # Added na=False to avoid issues with NaN values
    
    # Filter players based on minutes played (at least 1000 minutes)
    df = df[df['minutes'] >= 1000]

    # Clean up column names by stripping any leading/trailing spaces
    df.columns = df.columns.str.strip()

    # Convert specific columns to the appropriate data types
    if 'Gls' in df.columns:
        df['Gls'] = df['Gls'].astype(int)
    if 'PK' in df.columns:
        df['PK'] = df['PK'].astype(int)
    if 'npxG' in df.columns:
        df['npxG'] = df['npxG'].astype(float)

    # Create a column for non-penalty goals (npG)
    df['npG'] = (df['Gls']-df['PK']).round().astype(int)
    
    # Optional: Pivot the DataFrame if necessary (e.g., based on 'Statistic' and 'Percentile')
    #if 'Statistic' in df.columns and 'Percentile' in df.columns:
        #df = df.pivot_table(columns='Statistic', values='Percentile', aggfunc='mean')

    return df

# %%
# Call the function and save it to 'df' (alternatively safe it to 'clean_df')
df = clean_data(df)

# %%
# Check the dataframe again
df
# Out:
#         Rk             Player   Nation    Pos           Squad  \
# 6        7      Himad Abdelli   dz ALG  MF,FW          Angers
# 13      14     Matthis Abline   fr FRA     FW          Nantes
# 15      16  Zakaria Aboukhlal   ma MAR  MF,FW        Toulouse
# 18      19      Tammy Abraham  eng ENG     FW           Milan
# 23      24         Akor Adams   ng NGA     FW     Montpellier
# ...    ...                ...      ...    ...             ...
# 2931  2820  Alessandro Zanoli   it ITA  FW,DF           Genoa
# 2935  2824     Bryan Zaragoza   es ESP  FW,MF         Osasuna
# 2936  2825      Anass Zaroury   ma MAR  FW,MF            Lens
# 2954  2842     Joshua Zirkzee   nl NED  FW,MF  Manchester Utd
# 2966  2853        Milan Đurić   ba BIH     FW           Monza
#
#                     Comp Age  Born   90s  Gls  ... FK PK PKatt    xG npxG  \
# 6             fr Ligue 1  24  1999  31.6    6  ...  0  3     4   6.4  3.2
# ...

# %%
def calculate_performance_flags(df):
    """
    Calculate z-scores for goal overperformance (Gls - npxG),
    calculate median values, and flag overperforming and underperforming players.
    
    Parameters:
        df (pd.DataFrame): The cleaned DataFrame with 'Gls' and 'npxG' columns.
    
    Returns:
        pd.DataFrame: The modified DataFrame with added z-scores and performance flags.
    """
    # Step 1: Calculate overperformance (difference between goals and npxG)
    df['overperformance'] = df['npG'] - df['npxG']

    # Step 2: Calculate mean and std deviation of overperformance
    mean_over = df['overperformance'].mean()
    std_over = df['overperformance'].std()

    # Step 3: Calculate z-score for overperformance
    df['z_score_overperformance'] = (df['overperformance'] - mean_over) / std_over

    # Step 4: Calculate median overperformance
    median_over = df['overperformance'].median()

    # Step 5: Add flags for overperforming and underperforming
    df['overperforming'] = (df['z_score_overperformance'] > 0) & (df['overperformance'] > median_over)
    df['underperforming'] = (df['z_score_overperformance'] < 0) & (df['overperformance'] < median_over)

    # Step 6: Subsets (optional)
    overperforming_players = df[df['overperforming']]
    underperforming_players = df[df['underperforming']]

    return df, overperforming_players, underperforming_players

# %%
# Call the function
calculate_performance_flags(df)
# Out:
# (        Rk             Player   Nation    Pos           Squad  \
#  6        7      Himad Abdelli   dz ALG  MF,FW          Angers
#  13      14     Matthis Abline   fr FRA     FW          Nantes
#  15      16  Zakaria Aboukhlal   ma MAR  MF,FW        Toulouse
#  18      19      Tammy Abraham  eng ENG     FW           Milan
#  23      24         Akor Adams   ng NGA     FW     Montpellier
#  ...    ...                ...      ...    ...             ...
#  2931  2820  Alessandro Zanoli   it ITA  FW,DF           Genoa
#  2935  2824     Bryan Zaragoza   es ESP  FW,MF         Osasuna
#  2936  2825      Anass Zaroury   ma MAR  FW,MF            Lens
#  2954  2842     Joshua Zirkzee   nl NED  FW,MF  Manchester Utd
#  2966  2853        Milan Đurić   ba BIH     FW           Monza
#
#                      Comp Age  Born   90s  Gls  ... npxG npxG/Sh  G-xG np:G-xG  \
#  6             fr Ligue 1  24  1999  31.6    6  ...  3.2    0.09  -0.4    -0.2
# ...

# %%
df.head(10)
# Out:
#     Rk             Player   Nation    Pos        Squad                Comp  \
# 6    7      Himad Abdelli   dz ALG  MF,FW       Angers          fr Ligue 1
# 13  14     Matthis Abline   fr FRA     FW       Nantes          fr Ligue 1
# 15  16  Zakaria Aboukhlal   ma MAR  MF,FW     Toulouse          fr Ligue 1
# 18  19      Tammy Abraham  eng ENG     FW        Milan          it Serie A
# 23  24         Akor Adams   ng NGA     FW  Montpellier          fr Ligue 1
# 24  25          Che Adams  sct SCO     FW       Torino          it Serie A
# 27  27       Junior Adamu   at AUT     FW     Freiburg       de Bundesliga
# 30  30      Karim Adeyemi   de GER  FW,MF     Dortmund       de Bundesliga
# 31  31      Simon Adingra   ci CIV  FW,MF     Brighton  eng Premier League
# 38  38   Oladapo Afolayan  eng ENG  FW,MF    St. Pauli       de Bundesliga
#
#    Age  Born   90s  Gls  ... npxG npxG/Sh  G-xG np:G-xG minutes npG  \
# 6   24  1999  31.6    6  ...  3.2    0.09  -0.4    -0.2    2844   3
# ...

# %%
# Step 1: Compute median minutes played
median_minutes = df['minutes'].median()

# Step 2: Filter players with minutes above median
eligible_players = df[df['minutes'] > median_minutes]

# Step 3: Sort by overperformance (or z-score)
top_overperformers = eligible_players.sort_values(by='z_score_overperformance', ascending=False).head(10)

# Step 4: Optional — Select/display only relevant columns
top_overperformers = top_overperformers[['Player', 'Squad', 'minutes', 
                                         'Sh/90', 'SoT/90', 'npG', 'npxG', 'Gls',
                                         'overperformance', 'z_score_overperformance']]

# %%
top_overperformers
# Out:
#                Player            Squad  minutes Sh/90 SoT/90  npG  npxG  Gls  \
# 1760     Bryan Mbeumo        Brentford     3411  2.08   0.90   15   7.5   20
# 662     Matheus Cunha           Wolves     2601  3.81   1.52   15   8.6   15
# 2171      Ayoze Pérez       Villarreal     1971  3.43   1.42   19  12.7   19
# 2289    Mateo Retegui         Atalanta     2385  3.74   1.21   21  14.9   25
# 2898       Chris Wood  Nott'ham Forest     2961  1.98   0.97   17  11.0   20
# 1758    Kylian Mbappé      Real Madrid     2907  4.71   2.32   24  18.6   31
# 2595    Lucas Stassin    Saint-Étienne     1890  2.10   1.10   12   7.0   12
# 1102  Mason Greenwood        Marseille     2808  3.56   1.44   14   9.1   21
# 2255   Sandro Ramírez       Las Palmas     2034  2.26   0.88    8   3.3    9
# 1573  Ademola Lookman         Atalanta     2250  3.24   1.28   14   9.5   15
#
#       overperformance  z_score_overperformance
# 1760              7.5                 3.580651
# ...

# %%
# Create a function that takes only certain columns from the 'top_overperformers' dataframe
def create_dataframe_for_table(df):
    """
    Selects specific columns from the input DataFrame and returns a new DataFrame.

    Parameters:
    - df: The input DataFrame.

    Returns:
    - A DataFrame with only the selected columns: Player, Squad, minutes, Gls, 
    Sh/90, SoT/90, npxG, np:G-xG, PK.
    """
    table_df = df[['Player', 'Squad', 'minutes', 'Sh/90', 'SoT/90',
                   'Gls', 'npG', 'npxG', 'overperformance', ]]
    table_df['overperformance'] = table_df['overperformance'].round(2).astype(float)

    return table_df

# %%
table_df = create_dataframe_for_table(top_overperformers)
# Out:
# /var/folders/vw/4r9rm0553n95pm4ckhlrdctr0000gn/T/ipykernel_20206/2095657498.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table_df['overperformance'] = table_df['overperformance'].round(2).astype(float)

# %%
table_df
# Out:
#                Player            Squad  minutes Sh/90 SoT/90  Gls  npG  npxG  \
# 1760     Bryan Mbeumo        Brentford     3411  2.08   0.90   20   15   7.5
# 662     Matheus Cunha           Wolves     2601  3.81   1.52   15   15   8.6
# 2171      Ayoze Pérez       Villarreal     1971  3.43   1.42   19   19  12.7
# 2289    Mateo Retegui         Atalanta     2385  3.74   1.21   25   21  14.9
# 2898       Chris Wood  Nott'ham Forest     2961  1.98   0.97   20   17  11.0
# 1758    Kylian Mbappé      Real Madrid     2907  4.71   2.32   31   24  18.6
# 2595    Lucas Stassin    Saint-Étienne     1890  2.10   1.10   12   12   7.0
# 1102  Mason Greenwood        Marseille     2808  3.56   1.44   21   14   9.1
# 2255   Sandro Ramírez       Las Palmas     2034  2.26   0.88    9    8   3.3
# 1573  Ademola Lookman         Atalanta     2250  3.24   1.28   15   14   9.5
#
#       overperformance
# 1760              7.5
# 662               6.4
# 2171              6.3
# 2289              6.1
# ...

# %%
# Create a function to get each players's club's logo
def ax_logo(team_id, ax, team_id_dict):
    '''
    Plots the logo of the team at a specific axes.
    Args:
        team_id (int): the id of the team according to Fotmob. You can find it in the url of the team page.
        ax (object): the matplotlib axes where we'll draw the image.
    '''
    team_id = team_id_dict.get(team_id)
    if team_id is None:
        raise ValueError(f"Team ID for '{team_name}' not found in the dictionary.")
    fotmob_url = 'https://images.fotmob.com/image_resources/logo/teamlogo/'
    club_icon = Image.open(urllib.request.urlopen(f'{fotmob_url}{team_id}.png'))
    ax.imshow(club_icon)
    ax.axis('off')
    return ax

# %%
team_id_dict = {
    'Atalanta': 8524,
    'Brentford': 9937 ,
    'Las Palmas': 8306 ,
    'Marseille': 8592,
    "Nott'ham Forest": 10203,
    'Real Madrid': 8633,
    'Saint-Étienne': 9853,
    'Villarreal': 10205,
    'Wolves': 8602,
}

# %%
def create_another_table(df):
    df = table_df.sort_values(by='overperformance', ascending=True).reset_index(drop=True)
    df = df.rename(columns={'minutes': 'Mins', 'overperformance': 'Overperformance'})
    df['Overperformance'] = df['Overperformance'].apply(lambda x: f'+{x:.1f}' if x > 0 else f'{x:.1f}')

    fig = plt.figure(figsize=(14,6), dpi=300, facecolor='#F1E5E1')
    ax = plt.subplot()
    
    ncols = len(df.columns) + 1  # Dynamically calculate number of columns
    nrows = df.shape[0]
    
    ax.set_xlim(0.4, ncols + 1)
    ax.set_ylim(0, nrows + 1)
    
    # Dynamically generate column positions based on the number of columns
    step_sizes = [0.7, 3, 1, 0.85, 0.85, 0.85, 0.85, 0.85, 1.1]
    positions = [sum(step_sizes[:i+1]) for i in range(ncols)]
    columns = df.columns.tolist()  # Use the dataframe columns directly
    
    # Add table's main text
    for i in range(nrows):
        for j, column in enumerate(columns):
            if j == 0:
                ha = 'left'
            else:
                ha = 'center'
            text_label = f'{df[column].iloc[i]}'
            weight = 'normal'
            if column == 'Overperformance':
                weight = 'bold'
            ax.annotate(
                xy=(positions[j], i + .5),
                text=text_label,
                ha=ha,
                va='center',
                weight=weight
            )
    
    DC_to_FC = ax.transData.transform
    FC_to_NFC = fig.transFigure.inverted().transform
    
    DC_to_NFC = lambda x: FC_to_NFC(DC_to_FC(x))
    
    ax_point_1 = DC_to_NFC([0.95, 0.95])
    ax_point_2 = DC_to_NFC([0.25, 0.25])
    ax_width = abs(ax_point_1[0] - ax_point_2[0])
    ax_height = abs(ax_point_1[0] - ax_point_2[0])
    
    # Add logos for each team
    for x in range(0, nrows):
        ax_coords = DC_to_NFC([2.25, x + 0.15])
        badge_ax = fig.add_axes(
            [ax_coords[0], ax_coords[1], ax_width, ax_height]
        )
        team_name = df['Squad'].iloc[x]
        team_id = team_id_dict.get(team_name)  # Fetch team_id from the dictionary
        ax_logo(team_name, badge_ax, team_id_dict)
    
    # Add column names at the top
    for index, c in enumerate(columns):
            ha = 'left' if index == 0 else 'center'
            ax.annotate(
                xy=(positions[index], nrows + .25),
                text=c,
                ha=ha,
                va='bottom',
                weight='bold'
            )
    
    # Add dividing lines
    ax.plot([ax.get_xlim()[0], ax.get_xlim()[1]], [nrows, nrows], lw=1.5, color='black', marker='', zorder=4)
    ax.plot([ax.get_xlim()[0], ax.get_xlim()[1]], [0, 0], lw=1.5, color='black', marker='', zorder=4)
    for x in range(1, nrows):
        ax.plot([ax.get_xlim()[0], ax.get_xlim()[1]], [x, x], lw=1.15, color='gray', ls=':', zorder=3 , marker='')
    
    # Add title to the table
    fig.text(0.5, 0.95, "Top 10 forwards in Europe's Big 5 Leagues", ha='center', va='bottom', fontsize=14, weight='bold', color='#5A5A5A')
    # Add subtitle to the table
    fig.text(0.5, 0.9, "Based on non-penalty goals (npG) and non-penalty expected Goals (npxG), sorted by overperformance | Season 2024-25", ha='center', va='bottom', fontsize=12, color='#5A5A5A')
    # Add annotation at the bottom-left corner
    fig.text(0.1, 0.05, "Viz by jsonrbrt.bsky.social | data from FBRef.com", ha='left', va='bottom', fontsize=8, color='#5A5A5A')

    ax.set_axis_off()
    plt.savefig('top_overperformers.png', dpi=300, bbox_inches='tight', facecolor=fig.get_facecolor())

# %%
create_another_table(table_df)
